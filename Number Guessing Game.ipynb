# %%
# Number Guessing Game
import random 
user = int(input("Guess the number from 1-100 : "))
if user == random.randint(1,100):
    print("You Guessed it right !!!")
else:
    print("Try Again")
# Out:
# Try Again

# %%
import random 

number = random.randint(1,100)

while True:
    user = int(input("Guess the number from 1-100 :"))
    
    if user == number:
        print("You Guessed the right number !!!")
        break
    elif user > number:
        print("Too high, Try again.", user)
    else:
        print("Too low, Try again.", user)
# Out:
# Too low, Try again. 34
# Too low, Try again. 66
# Too high, Try again. 99
# Too low, Try again. 88
# You Guessed the right number !!!

# %%
import random

number = random.randint(1,100)
attempts = random.randint(1,10)
print(f"You will get {attempts} attempts.")

for i in range(attempts):
    user = float(input(f"Enter your guess:"))
   
    if user == number:
        print("You Guessed the right number !!!")
        break
    elif user > number:
        print("Too high, Try again.", user)
    else:
        print("Too low, Try again.", user) 
    
    if attempts - (i + 1) > 1:    
        print("Attempts left :", attempts - (i + 1))   
    elif attempts - (i + 1) == 1:
        print(f"Last attempt left.")    
    else:
        print(f"You are out of attempts. The number was {number}.")
# Out:
# You will get 6 attempts.
# Too high, Try again. 44.0
# Attempts left : 5
# Too high, Try again. 44.0
# Attempts left : 4
# Too high, Try again. 44.0
# Attempts left : 3
# Too high, Try again. 44.0
# Attempts left : 2
# Too high, Try again. 44.0
# Last attempt left.
# Too high, Try again. 44.0
# You are out of attempts. The number was 34.
